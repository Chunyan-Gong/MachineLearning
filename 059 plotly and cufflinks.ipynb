# %%
import pandas as pd

# %%
import numpy as np

# %%
# %matplotlib inline

# %%
import sys
# !{sys.executable} -m pip install plotly

# %%
import sys
# !{sys.executable} -m pip install cufflinks

# %%
# Import the necessaries libraries
import plotly.offline as pyo
import plotly.graph_objs as go

# %%
from plotly import __version__

# %%
print(__version__)
# Out:
# 3.10.0

# %%
import cufflinks as cf

# %%
'''
plotly is a Python library which is used to design graphs, 
especially interactive graphs. It can plot various graphs and charts like histogram, barplot, boxplot, spreadplot and many more. 
It is mainly used in data analysis as well as financial analysis. plotly is an interactive visualization library.
cufflink connects plotly with pandas to create graphs and charts of dataframes directly. 
choropleth is used to describe geographical plotting of USA. choropleth is used in the plotting of world maps and many more.
'''
# Out:
# '\nplotly is a Python library which is used to design graphs, \nespecially interactive graphs. It can plot various graphs and charts like histogram, barplot, boxplot, spreadplot and many more. \nIt is mainly used in data analysis as well as financial analysis. plotly is an interactive visualization library.\ncufflink connects plotly with pandas to create graphs and charts of dataframes directly. \nchoropleth is used to describe geographical plotting of USA. choropleth is used in the plotting of world maps and many more.\n'

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

# %%
init_notebook_mode(connected=True) #connect the java script to my notebook, make my notebook access to the visualizations
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#pyo.init_notebook_mode()

# %%
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df1=pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())
df1.head()
# Out:
#           A         B         C         D
# 0  0.104646 -0.971183  1.517992  0.151340
# 1  0.271449  0.523552 -2.204489  0.723141
# 2  0.428654  0.679552  1.384424 -0.663815
# 3  2.279981  1.008923 -0.987437 -0.384891
# 4 -0.431249  0.224167  0.671778  0.952269

# %%
df2=pd.DataFrame({'category':['A','B','C'],'values':[32,43,50]})
df2
# Out:
#   category  values
# 0        A      32
# 1        B      43
# 2        C      50

# %%
df1.plot()

# %%
# %matplotlib inline
df1.iplot()

'''
df1.iplot(kind='scatter'x='A',y='B',mode='markers')
df1.iplot(kind='bar')
'''
# Out:
# <div>
#
#
#             <div id="9f64ded7-55e1-45a7-b7a8-7377bbe75a07" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9f64ded7-55e1-45a7-b7a8-7377bbe75a07")) {
#                     Plotly.newPlot(
#                         '9f64ded7-55e1-45a7-b7a8-7377bbe75a07',
# ...

# %%
df1.iplot(kind='scatter',x='A',y='B')  #in plotly, scatter is defualt by connecting with lines, so we need to specify the mode
# Out:
# <div>
#
#
#             <div id="af6dff9b-8a5e-4e55-8891-e610bd0a5412" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("af6dff9b-8a5e-4e55-8891-e610bd0a5412")) {
#                     Plotly.newPlot(
#                         'af6dff9b-8a5e-4e55-8891-e610bd0a5412',
# ...

# %%
df1.iplot(kind='scatter',x='A',y='B',mode='markers',size=10)
# Out:
# <div>
#
#
#             <div id="5ff5a005-09c8-499a-bbff-6137043cec33" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5ff5a005-09c8-499a-bbff-6137043cec33")) {
#                     Plotly.newPlot(
#                         '5ff5a005-09c8-499a-bbff-6137043cec33',
# ...

# %%
df2.iplot(kind='bar',x='category',y='values')
# Out:
# <div>
#
#
#             <div id="62b427c5-98e8-4a22-9e86-fc9650bb348d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("62b427c5-98e8-4a22-9e86-fc9650bb348d")) {
#                     Plotly.newPlot(
#                         '62b427c5-98e8-4a22-9e86-fc9650bb348d',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "values", "orientation": "v", "text": "", "type": "bar", "uid": "9220e23c-3bd6-4dc7-84ab-084d7a7520b4", "x": ["A", "B", "C"], "y": [32, 43, 50]}],
# ...

# %%
#we can deal with initial data and the plot them out

# %%
df1.mean().iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="aadacf5a-d37a-4e98-bdf3-899883f02668" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("aadacf5a-d37a-4e98-bdf3-899883f02668")) {
#                     Plotly.newPlot(
#                         'aadacf5a-d37a-4e98-bdf3-899883f02668',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "uid": "b16c4146-75eb-4c81-b044-38fbe5071bdc", "x": ["A", "B", "C", "D"], "y": [0.23063410457427744, -0.04452667124555198, 0.029246456036429773, 0.11263935547374562]}],
# ...

# %%
df1.count().iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="08426b4d-3fea-4118-883e-897efc4fe03c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("08426b4d-3fea-4118-883e-897efc4fe03c")) {
#                     Plotly.newPlot(
#                         '08426b4d-3fea-4118-883e-897efc4fe03c',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "uid": "5222ed30-3345-483f-ba01-5e957e990ec7", "x": ["A", "B", "C", "D"], "y": [100, 100, 100, 100]}],
# ...

# %%
df1.sum().iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="26cfbc3b-aa56-436e-8f6e-3e8152f81584" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("26cfbc3b-aa56-436e-8f6e-3e8152f81584")) {
#                     Plotly.newPlot(
#                         '26cfbc3b-aa56-436e-8f6e-3e8152f81584',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "uid": "faac718c-7ed1-44c9-b49c-d77bcc3de8f3", "x": ["A", "B", "C", "D"], "y": [23.063410457427743, -4.452667124555198, 2.9246456036429773, 11.263935547374562]}],
# ...

# %%
#box plots
df1.iplot(kind='box')
# Out:
# <div>
#
#
#             <div id="4a8850ef-d7d7-474c-8c7b-62d8f6d3dd93" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("4a8850ef-d7d7-474c-8c7b-62d8f6d3dd93")) {
#                     Plotly.newPlot(
#                         '4a8850ef-d7d7-474c-8c7b-62d8f6d3dd93',
# ...

# %%
#哇靠 这样处理数据超快的！

# %%
df3=pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[500,400,300,200,100]})
df3

'''
这个dataframe的意义就在于其是一个三维的东西，更直观的展示三维的东西，那么四维的可不可以呢？

'''
# Out:
#    x   y    z
# 0  1  10  500
# 1  2  20  400
# 2  3  30  300
# 3  4  20  200
# 4  5  10  100

# %%
df3.iplot(kind='surface')
# Out:
# <div>
#
#
#             <div id="28238239-e4c0-4117-b506-c090b580697f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("28238239-e4c0-4117-b506-c090b580697f")) {
#                     Plotly.newPlot(
#                         '28238239-e4c0-4117-b506-c090b580697f',
# ...

# %%
df4=pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[5,4,3,2,1]})
df4.iplot(kind='surface')
# Out:
# <div>
#
#
#             <div id="718d788c-3e42-415f-89dd-2850fca8cd6c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("718d788c-3e42-415f-89dd-2850fca8cd6c")) {
#                     Plotly.newPlot(
#                         '718d788c-3e42-415f-89dd-2850fca8cd6c',
# ...

# %%
'''
会发现surface上面的并不是点，而是切面
'''

# %%
#we can change the colorscale
df4.iplot(kind='surface',colorscale='rdylbu')
# Out:
# <div>
#
#
#             <div id="5eb5b391-0c71-471b-b6ef-94f3a69dd91a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5eb5b391-0c71-471b-b6ef-94f3a69dd91a")) {
#                     Plotly.newPlot(
#                         '5eb5b391-0c71-471b-b6ef-94f3a69dd91a',
# ...

# %%
df1.iplot(kind='hist',bins=50)  #这里是将df中所有的图都画出来了，可以根据需要来看，好酷
# Out:
# <div>
#
#
#             <div id="8b3f8e03-d0f3-4870-9aab-4f09175dabc5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8b3f8e03-d0f3-4870-9aab-4f09175dabc5")) {
#                     Plotly.newPlot(
#                         '8b3f8e03-d0f3-4870-9aab-4f09175dabc5',
# ...

# %%
#we can calculate and plot out the spread of two series, 这个在计算价差的时候非常重要
df[['A','B']].iplot(kind='spread')
# Out:
# <div>
#
#
#             <div id="edee0fa9-2a96-4486-a7ad-1c9e3c585d6b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("edee0fa9-2a96-4486-a7ad-1c9e3c585d6b")) {
#                     Plotly.newPlot(
#                         'edee0fa9-2a96-4486-a7ad-1c9e3c585d6b',
# ...

# %%
'''
here i have a question, why the green plots are continuous ?
'''
# Out:
# '\nhere i have a question, why the green plots are continuous ?\n'

# %%
#bubble plot
df1.iplot(kind='bubble',x='A',y='B',size='C') 


'''
every bubble has a pair of data as well as has a size, the size is the value of C
But how to caculate the size of bubble? and why so many bubbles are gathered together ? what does this figure mean?
1) the size is the value of C, so we don't need to calculate it 
2) the bubbles are gathered together because these data are close to each other 
3)Bubble chart with plotly.express
A bubble chart is a scatter plot in which a third dimension of the data is shown through the size of markers. 
For other types of scatter plot, see the line and scatter page.
'''
# Out:
# <div>
#
#
#             <div id="a447bfa7-701b-4cf7-9906-7a44a03836b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("a447bfa7-701b-4cf7-9906-7a44a03836b5")) {
#                     Plotly.newPlot(
#                         'a447bfa7-701b-4cf7-9906-7a44a03836b5',
# ...

# %%
#scatter_matrix
df1.scatter_matrix()

'''
there are ABCD four columns, so we have a 4*4 grid
the diagonal line has the histgrapg of each column 
the rest are scatter plots 
'''
# Out:
# <div>
#
#
#             <div id="5904d56f-2e88-4f67-9a92-46b31316864f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5904d56f-2e88-4f67-9a92-46b31316864f")) {
#                     Plotly.newPlot(
#                         '5904d56f-2e88-4f67-9a92-46b31316864f',
# ...

# %%
#more information, see github.com/santosjorge/cufflinks
#check out cufflinks tutorials
#there are some beta cufflinks functions 

#ta.py  technical analysis
